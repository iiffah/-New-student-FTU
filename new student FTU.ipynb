# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
df = pd.read_excel("นักศึกษาเข้าปี64.xlsx")
df
# Out:
#      FINALACADYEAR  FINALSEMESTER  STUDENTCODE PREFIXNAME    STUDENTNAME  \
# 0             2564              1    642411013     นางสาว          มัสนา
# 1             2564              1    641413001        นาย         มุสอับ
# 2             2564              1    641411005        นาย        มะซาเฮะ
# 3             2564              1    641442014        นาย          ดานิส
# 4             2564              1    641447004        นาย  มูฮำหมัดฟาอิฟ
# ..             ...            ...          ...        ...            ...
# 698           2564              1    642424048     นางสาว       ลาตีกะห์
# 699           2564              1    641431001        นาย         ติณห์
# 700           2564              1    641421017        นาย           สุธี
# 701           2564              1    642424068     นางสาว       กอมารียา
# 702           2564              1    642424017     นางสาว         ตัสนีม
#
#     STUDENTSURNAME STUDENTSEX  อายุวันที่พ้นสภาพ  สถานภาพ (โสด/แต่งงาน/หม้าย)  \
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of      FINALACADYEAR  FINALSEMESTER  STUDENTCODE PREFIXNAME    STUDENTNAME  \
# 0             2564              1    642411013     นางสาว          มัสนา
# 1             2564              1    641413001        นาย         มุสอับ
# 2             2564              1    641411005        นาย        มะซาเฮะ
# 3             2564              1    641442014        นาย          ดานิส
# 4             2564              1    641447004        นาย  มูฮำหมัดฟาอิฟ
# ..             ...            ...          ...        ...            ...
# 698           2564              1    642424048     นางสาว       ลาตีกะห์
# 699           2564              1    641431001        นาย         ติณห์
# 700           2564              1    641421017        นาย           สุธี
# 701           2564              1    642424068     นางสาว       กอมารียา
# 702           2564              1    642424017     นางสาว         ตัสนีม
#
# ...

# %%
df.shape
# Out:
# (703, 34)

# %%
df.drop('ทุน (ชำระเอง/กยศ/อื่นๆ)', axis=1, inplace=True)

# %%
df.shape
# Out:
# (703, 33)

# %%
df.drop('วิธีการเข้าศึกษา (รับตรง/โควตา)', axis=1, inplace=True)

# %%
df.drop('OFFICENAME', axis=1, inplace=True)

# %%
df.drop('สถานภาพ (โสด/แต่งงาน/หม้าย)', axis=1, inplace=True)

# %%
df.drop('FINANCESTATUSDES', axis=1, inplace=True)

# %%
df.drop('อายุวันที่พ้นสภาพ', axis=1, inplace=True)

# %%
df.drop('FINISHDATE', axis=1, inplace=True)

# %%
df.shape
# Out:
# (703, 27)

# %%
df.GPA.hist();

# %%
df[['GPA', 'ENTRYGPA']].hist();

# %%
df[['GPA', 'ENTRYGPA']].hist(bins=20, grid=False, sharex=True, sharey=True);

# %%
df.GPA.plot.hist();

# %%
df.GPA.plot.density();

# %%
df.FACULTYNAME
# Out:
# 0      อิสลามศึกษาและนิติศาสตร์
# 1      อิสลามศึกษาและนิติศาสตร์
# 2      อิสลามศึกษาและนิติศาสตร์
# 3                   ศึกษาศาสตร์
# 4                   ศึกษาศาสตร์
#                  ...
# 698          สถาบันภาษานานาชาติ
# 699          สถาบันภาษานานาชาติ
# 700          สถาบันภาษานานาชาติ
# 701          สถาบันภาษานานาชาติ
# 702          สถาบันภาษานานาชาติ
# Name: FACULTYNAME, Length: 703, dtype: object

# %%
df.FACULTYNAME.value_counts()
# Out:
# ศึกษาศาสตร์                 301
# สถาบันภาษานานาชาติ          173
# อิสลามศึกษาและนิติศาสตร์    118
# ศิลปศาสตร์และสังคมศาสตร์     91
# วิทยาศาสตร์และเทคโนโลยี      20
# Name: FACULTYNAME, dtype: int64

# %%
df.FACULTYNAME.value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
plt.rcParams['font.family']='Tahoma'

# %%
df.FACULTYNAME.value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.FACULTYNAME.value_counts().plot.bar( title='FACULTY', figsize=(10, 5))
# Out:
# <AxesSubplot:title={'center':'FACULTY'}>

# %%
df.STUDENTSEX.value_counts().plot.barh()
# Out:
# <AxesSubplot:>

# %%
plt.rcParams['font.size']=16
df.STUDENTSEX.value_counts().plot.barh( title='STUDENTSEX', figsize=(20, 5))
# Out:
# <AxesSubplot:title={'center':'STUDENTSEX'}>

# %%
df.FACULTYNAME.value_counts().plot.barh(title='FACULTY')
# Out:
# <AxesSubplot:title={'center':'FACULTY'}>

# %%
plt.rcParams['font.size']=16
df.FACULTYNAME.value_counts().plot.barh(title='FACULTY')
# Out:
# <AxesSubplot:title={'center':'FACULTY'}>

# %%
df.HOMEPROVINCENAME.value_counts()
# Out:
# ปัตตานี            177
# ยะลา               159
# นราธิวาส           146
# สงขลา               47
# สตูล                36
# กรุงเทพ ฯ           34
# กระบี่              15
# -                   12
# พัทลุง              11
# นครศรีธรรมราช        6
# ฉะเชิงเทรา           6
# พังงา                6
# พระนครศรีอยุธยา      5
# นนทบุรี              5
# ภูเก็ต               4
# ระนอง                4
# สุราษฏร์ธานี         3
# สมุทรปราการ          3
# ปทุมธานี             3
# ชลบุรี               2
# สิงห์บุรี            1
# ประจวบคีรีขันธ์      1
# นครนายก              1
# หนองบัวลำภู          1
# Malaysia             1
# เพชรบุรี             1
# สระบุรี              1
# แพร่                 1
# ชุมพร                1
# China                1
# เชียงราย             1
# ชัยภูมิ              1
# เชียงใหม่            1
# Name: HOMEPROVINCENAME, dtype: int64

# %%
plt.rcParams['font.size']=8
df.HOMEPROVINCENAME.value_counts().plot.barh(title='HOME PROVINCENAME', figsize=(20, 5))
# Out:
# <AxesSubplot:title={'center':'HOME PROVINCENAME'}>

# %%
df.HOMEPROVINCENAME.value_counts().plot(kind='line', title='Student province', figsize=(20, 5))
ax.set_xlabel('job dad')
ax.set_ylabel('')
# Out:
# Text(6.400000000000034, 0.5, '')

# %%
ax = df.FAT_OCCUP_ID.value_counts().plot(kind='line', figsize=(15, 5))
ax.set_xlabel('job dad')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
plt.rcParams['font.size']=14
df.FAT_OCCUP_ID.value_counts().plot.barh(title='อาชีพของบิดา', figsize=(10, 5))
# Out:
# <AxesSubplot:title={'center':'อาชีพของบิดา'}>

# %%
df.loc[(df.HOMEPROVINCENAME=="กระบี่"),'zone'] = 'South'
df.loc[(df.HOMEPROVINCENAME=="ชุมพร"),'zone'] = 'South'
df.loc[(df.HOMEPROVINCENAME=="ตรัง"),'zone'] = 'South'
df.loc[(df.HOMEPROVINCENAME=="นครศรีธรรมราช"),'zone'] = 'South'
df.loc[(df.HOMEPROVINCENAME=="นราธิวาส"),'zone'] = 'South'
df.loc[(df.HOMEPROVINCENAME=="ปัตตานี"),'zone'] = 'South'
df.loc[(df.HOMEPROVINCENAME=="พังงา"),'zone'] = 'South'
df.loc[(df.HOMEPROVINCENAME=="พัทลุง"),'zone'] = 'South'
df.loc[(df.HOMEPROVINCENAME=="ภูเก็ต"),'zone'] = 'South'
df.loc[(df.HOMEPROVINCENAME=="ระนอง"),'zone'] = 'South'
df.loc[(df.HOMEPROVINCENAME=="สตูล"),'zone'] = 'South'
df.loc[(df.HOMEPROVINCENAME=="สงขลา"),'zone'] = 'South'
df.loc[(df.HOMEPROVINCENAME=="สุราษฎร์ธานี"),'zone'] = 'South'
df.loc[(df.HOMEPROVINCENAME=="ยะลา"),'zone'] = 'South'

# %%
df.loc[(df.HOMEPROVINCENAME=="กาฬสินธุ์ "),'zone'] = 'Northeast'
df.loc[(df.HOMEPROVINCENAME=="ขอนแก่น "),'zone'] = 'Northeast'
df.loc[(df.HOMEPROVINCENAME=="ชัยภูมิ "),'zone'] = 'Northeast'
df.loc[(df.HOMEPROVINCENAME=="นครพนม "),'zone'] = 'Northeast'
df.loc[(df.HOMEPROVINCENAME=="นครราชสีมา "),'zone'] = 'Northeast'
df.loc[(df.HOMEPROVINCENAME=="บึงกาฬ "),'zone'] = 'Northeast'
df.loc[(df.HOMEPROVINCENAME=="บุรีรัมย์ "),'zone'] = 'Northeast'
df.loc[(df.HOMEPROVINCENAME=="มหาสารคาม "),'zone'] = 'Northeast'
df.loc[(df.HOMEPROVINCENAME=="มุกดาหาร "),'zone'] = 'Northeast'
df.loc[(df.HOMEPROVINCENAME=="ยโสธร "),'zone'] = 'Northeast'
df.loc[(df.HOMEPROVINCENAME=="ร้อยเอ็ด "),'zone'] = 'Northeast'
df.loc[(df.HOMEPROVINCENAME=="เลย "),'zone'] = 'Northeast'
df.loc[(df.HOMEPROVINCENAME=="สกลนคร "),'zone'] = 'Northeast'
df.loc[(df.HOMEPROVINCENAME=="สุรินทร์ "),'zone'] = 'Northeast'
df.loc[(df.HOMEPROVINCENAME=="ศรีสะเกษ "),'zone'] = 'Northeast'
df.loc[(df.HOMEPROVINCENAME=="หนองคาย "),'zone'] = 'Northeast'
df.loc[(df.HOMEPROVINCENAME=="หนองบัวลำภู  "),'zone'] = 'Northeast'
df.loc[(df.HOMEPROVINCENAME=="อุดรธานี "),'zone'] = 'Northeast'
df.loc[(df.HOMEPROVINCENAME=="อุบลราชธานี "),'zone'] = 'Northeast'
df.loc[(df.HOMEPROVINCENAME=="อำนาจเจริญ "),'zone'] = 'Northeast'

# %%
df.loc[(df.HOMEPROVINCENAME=="เชียงราย  "),'zone'] = 'North'
df.loc[(df.HOMEPROVINCENAME=="เชียงใหม่ "),'zone'] = 'North'
df.loc[(df.HOMEPROVINCENAME=="น่าน "),'zone'] = 'North'
df.loc[(df.HOMEPROVINCENAME=="พะเยา "),'zone'] = 'North'
df.loc[(df.HOMEPROVINCENAME=="แพร่ "),'zone'] = 'North'
df.loc[(df.HOMEPROVINCENAME=="แม่ฮ่องสอน "),'zone'] = 'North'
df.loc[(df.HOMEPROVINCENAME=="ลำปาง "),'zone'] = 'North'
df.loc[(df.HOMEPROVINCENAME=="ลำพูน "),'zone'] = 'North'
df.loc[(df.HOMEPROVINCENAME=="อุตรดิตถ์ "),'zone'] = 'North'

# %%
df.loc[(df.HOMEPROVINCENAME=="กรุงเทพฯ "),'zone'] = 'Central'
df.loc[(df.HOMEPROVINCENAME=="กำแพงเพชร "),'zone'] = 'Central'
df.loc[(df.HOMEPROVINCENAME=="ชัยนาท "),'zone'] = 'Central'
df.loc[(df.HOMEPROVINCENAME=="นครนายก "),'zone'] = 'Central'
df.loc[(df.HOMEPROVINCENAME=="นครปฐม "),'zone'] = 'Central'
df.loc[(df.HOMEPROVINCENAME=="นครสวรรค์ "),'zone'] = 'Central'
df.loc[(df.HOMEPROVINCENAME=="นนทบุรี "),'zone'] = 'Central'
df.loc[(df.HOMEPROVINCENAME=="ปทุมธานี "),'zone'] = 'Central'
df.loc[(df.HOMEPROVINCENAME=="พระนครศรีอยุธยา "),'zone'] = 'Central'
df.loc[(df.HOMEPROVINCENAME=="พิจิตร "),'zone'] = 'Central'
df.loc[(df.HOMEPROVINCENAME=="พิษณุโลก "),'zone'] = 'Central'
df.loc[(df.HOMEPROVINCENAME=="เพชรบูรณ์ "),'zone'] = 'Central'
df.loc[(df.HOMEPROVINCENAME=="ลพบุรี "),'zone'] = 'Central'
df.loc[(df.HOMEPROVINCENAME=="สมุทรปราการ "),'zone'] = 'Central'
df.loc[(df.HOMEPROVINCENAME=="สมุทรสงคราม "),'zone'] = 'Central'
df.loc[(df.HOMEPROVINCENAME=="สมุทรสาคร "),'zone'] = 'Central'
df.loc[(df.HOMEPROVINCENAME=="สิงห์บุรี  "),'zone'] = 'Central'
df.loc[(df.HOMEPROVINCENAME=="สุโขทัย  "),'zone'] = 'Central'
df.loc[(df.HOMEPROVINCENAME=="สุพรรณบุรี "),'zone'] = 'Central'
df.loc[(df.HOMEPROVINCENAME=="สระบุรี "),'zone'] = 'Central'
df.loc[(df.HOMEPROVINCENAME=="อ่างทอง "),'zone'] = 'Central'
df.loc[(df.HOMEPROVINCENAME=="อุทัยธานี "),'zone'] = 'Central'

# %%
df.loc[(df.HOMEPROVINCENAME=="จันทบุรี "),'zone'] = 'East'
df.loc[(df.HOMEPROVINCENAME=="ฉะเชิงเทรา "),'zone'] = 'East'
df.loc[(df.HOMEPROVINCENAME=="ชลบุรี "),'zone'] = 'East'
df.loc[(df.HOMEPROVINCENAME=="ตราด "),'zone'] = 'East'
df.loc[(df.HOMEPROVINCENAME=="ปราจีนบุรี "),'zone'] = 'East'
df.loc[(df.HOMEPROVINCENAME=="ระยอง "),'zone'] = 'East'
df.loc[(df.HOMEPROVINCENAME=="สระแก้ว "),'zone'] = 'East'

# %%
df.loc[(df.HOMEPROVINCENAME=="กาญจนบุรี "),'zone'] = 'West'
df.loc[(df.HOMEPROVINCENAME=="ตาก "),'zone'] = 'West'
df.loc[(df.HOMEPROVINCENAME=="ประจวบคีรีขันธ์ "),'zone'] = 'West'
df.loc[(df.HOMEPROVINCENAME=="เพชรบุรี "),'zone'] = 'West'
df.loc[(df.HOMEPROVINCENAME=="ราชบุรี "),'zone'] = 'West'

# %%
df.HOMEPROVINCENAME.value_counts()
# Out:
# ปัตตานี            177
# ยะลา               159
# นราธิวาส           146
# สงขลา               47
# สตูล                36
# กรุงเทพ ฯ           34
# กระบี่              15
# -                   12
# พัทลุง              11
# นครศรีธรรมราช        6
# ฉะเชิงเทรา           6
# พังงา                6
# พระนครศรีอยุธยา      5
# นนทบุรี              5
# ภูเก็ต               4
# ระนอง                4
# สุราษฏร์ธานี         3
# สมุทรปราการ          3
# ปทุมธานี             3
# ชลบุรี               2
# สิงห์บุรี            1
# ประจวบคีรีขันธ์      1
# นครนายก              1
# หนองบัวลำภู          1
# Malaysia             1
# เพชรบุรี             1
# สระบุรี              1
# แพร่                 1
# ชุมพร                1
# China                1
# เชียงราย             1
# ชัยภูมิ              1
# เชียงใหม่            1
# Name: HOMEPROVINCENAME, dtype: int64

# %%
plt.rcParams['font.size']=8
df.HOMEPROVINCENAME.value_counts().plot.barh(title='HOME PROVINCENAME', figsize=(20, 5))
df.loc()
